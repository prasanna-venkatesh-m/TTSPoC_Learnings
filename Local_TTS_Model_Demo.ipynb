# %% [markdown]
# <a href="https://colab.research.google.com/github/prasanna-venkatesh-m/TTSPoC_Learnings/blob/main/Local_TTS_Model_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install librosa torch numpy

# %%
pip install coqui-tts
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.8/862.8 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 31.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.3/997.3 kB 40.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.4/648.4 kB 41.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 7.8 MB/s eta 0:00:00
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=da6e35fc4a2e1dfadd99e45fbd1c6874390da9286919a12d1fcf343be811748f
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# ...

# %%
import torch
from TTS.utils.manage import ModelManager
from TTS.utils.synthesizer import Synthesizer

# 1. Define your file paths
# Make sure these filenames match exactly what you downloaded
model_path = "/content/tamil.pt"
encoder_path = "/content/speaker_encoder.pt"
vocoder_path = "/content/hifigan.pt"

# AIKosh models usually need a config.json.
# If you don't have one, this script might error out.
config_path = "config.json"

# 2. Initialize the Synthesizer
syn = Synthesizer(
    tts_checkpoint=model_path,
    tts_config_path=config_path,
    speaker_encoder_checkpoint=encoder_path,
    vocoder_checkpoint=vocoder_path,
    use_cuda=torch.cuda.is_available() # Uses GPU if you have one
)

# 3. Your Tamil Text
text = "வணக்கம், இது செயற்கை நுண்ணறிவு மூலம் உருவாக்கப்பட்ட குரல்."

# 4. Generate and Save
print("Synthesizing audio...")
outputs = syn.tts(text)
syn.save_wav(outputs, "tamil_output.wav")
print("Done! Check tamil_output.wav")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7966/2895450086.py in <cell line: 0>()
#      14
#      15 # 2. Initialize the Synthesizer
# ---> 16 syn = Synthesizer(
#      17     tts_checkpoint=model_path,
#      18     tts_config_path=config_path,
#
# TypeError: Synthesizer.__init__() got an unexpected keyword argument 'speaker_encoder_checkpoint'
